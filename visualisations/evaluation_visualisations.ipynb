# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Evaluation of models trained with datasets using 4x 20y sequences as basis for which images to use

# %%
rainformer_4x9_1 = np.load('../results/metrics_rainformer_4x9y_03_12_epoch23-loss7600_4x9y_downsampled_first_1_outputs.npy', allow_pickle=True).item()
rainformer_4x9_2 = np.load('../results/metrics_rainformer_4x9y_03_12_epoch23-loss7600_4x9y_downsampled_first_2_outputs.npy', allow_pickle=True).item()
rainformer_4x9_4 = np.load('../results/metrics_rainformer_4x9y_03_12_epoch23-loss7600_4x9y_downsampled_first_4_outputs.npy', allow_pickle=True).item()
rainformer_4x9_6 = np.load('../results/metrics_rainformer_4x9y_03_12_epoch23-loss7600_4x9y_downsampled_first_6_outputs.npy', allow_pickle=True).item()
rainformer_4x9_9 = np.load('../results/metrics_rainformer_4x9y_03_12_epoch23-loss7600_4x9y_downsampled_first_9_outputs.npy', allow_pickle=True).item()

rainformer_pretrained_9x9_1 = np.load('../results/metrics_PreTrainModel_model1_1_100_9x9y_downsampled_first_1_outputs.npy', allow_pickle=True).item()
rainformer_pretrained_9x9_2 = np.load('../results/metrics_PreTrainModel_model1_1_100_9x9y_downsampled_first_2_outputs.npy', allow_pickle=True).item()
rainformer_pretrained_9x9_4 = np.load('../results/metrics_PreTrainModel_model1_1_100_9x9y_downsampled_first_4_outputs.npy', allow_pickle=True).item()
rainformer_pretrained_9x9_6 = np.load('../results/metrics_PreTrainModel_model1_1_100_9x9y_downsampled_first_6_outputs.npy', allow_pickle=True).item()
rainformer_pretrained_9x9_9 = np.load('../results/metrics_PreTrainModel_model1_1_100_9x9y_downsampled_first_9_outputs.npy', allow_pickle=True).item()

rainformer_rtcor_9x9_1 = np.load('../results/metrics_train_rainformer_9x9_consistent_data_epoch26-loss8224_9x9y_downsampled_first_1_outputs.npy', allow_pickle=True).item()
rainformer_rtcor_9x9_2 = np.load('../results/metrics_train_rainformer_9x9_consistent_data_epoch26-loss8224_9x9y_downsampled_first_2_outputs.npy', allow_pickle=True).item()
rainformer_rtcor_9x9_4 = np.load('../results/metrics_train_rainformer_9x9_consistent_data_epoch26-loss8224_9x9y_downsampled_first_4_outputs.npy', allow_pickle=True).item()
rainformer_rtcor_9x9_6 = np.load('../results/metrics_train_rainformer_9x9_consistent_data_epoch26-loss8224_9x9y_downsampled_first_6_outputs.npy', allow_pickle=True).item()
rainformer_rtcor_9x9_9 = np.load('../results/metrics_train_rainformer_9x9_consistent_data_epoch26-loss8224_9x9y_downsampled_first_9_outputs.npy', allow_pickle=True).item()

rainformer_rtcor_4x20_1 = np.load('../results/metrics_rainformer_ddp_24_11_epoch17-loss23997_4x20y_downsampled_first_1_outputs.npy', allow_pickle=True).item()
rainformer_rtcor_4x20_2 = np.load('../results/metrics_rainformer_ddp_24_11_epoch17-loss23997_4x20y_downsampled_first_2_outputs.npy', allow_pickle=True).item()
rainformer_rtcor_4x20_4 = np.load('../results/metrics_rainformer_ddp_24_11_epoch17-loss23997_4x20y_downsampled_first_4_outputs.npy', allow_pickle=True).item()
rainformer_rtcor_4x20_6 = np.load('../results/metrics_rainformer_ddp_24_11_epoch17-loss23997_4x20y_downsampled_first_6_outputs.npy', allow_pickle=True).item()
rainformer_rtcor_4x20_9 = np.load('../results/metrics_rainformer_ddp_24_11_epoch17-loss23997_4x20y_downsampled_first_9_outputs.npy', allow_pickle=True).item()

rainformer_rtcor_6x9_1 = np.load('../results/metrics_train_rainformer_6x9_30_6x9y_first_1_outputs.npy', allow_pickle=True).item()
rainformer_rtcor_6x9_2 = np.load('../results/metrics_train_rainformer_6x9_30_6x9y_first_2_outputs.npy', allow_pickle=True).item()
rainformer_rtcor_6x9_4 = np.load('../results/metrics_train_rainformer_6x9_30_6x9y_first_4_outputs.npy', allow_pickle=True).item()
rainformer_rtcor_6x9_6 = np.load('../results/metrics_train_rainformer_6x9_30_6x9y_first_6_outputs.npy', allow_pickle=True).item()
rainformer_rtcor_6x9_9 = np.load('../results/metrics_train_rainformer_6x9_30_6x9y_first_9_outputs.npy', allow_pickle=True).item()

# %%
lead_times = [1, 2, 4, 6, 9]
lead_times_mins = [lt * 5 for lt in lead_times]

csi_values_4x9 = [rainformer_4x9_1['csi_down'], rainformer_4x9_2['csi_down'], rainformer_4x9_4['csi_down'], rainformer_4x9_6['csi_down'], rainformer_4x9_9['csi_down']]
csi_values_4x9 = np.array(csi_values_4x9).T

csi_values_pretrained = [rainformer_pretrained_9x9_1['csi_down'], rainformer_pretrained_9x9_2['csi_down'], rainformer_pretrained_9x9_4['csi_down'], rainformer_pretrained_9x9_6['csi_down'], rainformer_pretrained_9x9_9['csi_down']]
csi_values_pretrained = np.array(csi_values_pretrained).T

csi_values_rtcor_9x9 = [rainformer_rtcor_9x9_1['csi_down'], rainformer_rtcor_9x9_2['csi_down'], rainformer_rtcor_9x9_4['csi_down'], rainformer_rtcor_9x9_6['csi_down'], rainformer_rtcor_9x9_9['csi_down']]
csi_values_rtcor_9x9 = np.array(csi_values_rtcor_9x9).T

csi_values_rtcor_4x20 = [rainformer_rtcor_4x20_1['csi_down'], rainformer_rtcor_4x20_2['csi_down'], rainformer_rtcor_4x20_4['csi_down'], rainformer_rtcor_4x20_6['csi_down'], rainformer_rtcor_4x20_9['csi_down']]
csi_values_rtcor_4x20 = np.array(csi_values_rtcor_4x20).T

csi_values_rtcor_6x9 = [rainformer_rtcor_6x9_1['csi_down'], rainformer_rtcor_6x9_2['csi_down'], rainformer_rtcor_6x9_4['csi_down'], rainformer_rtcor_6x9_6['csi_down'], rainformer_rtcor_6x9_9['csi_down']]
csi_values_rtcor_6x9 = np.array(csi_values_rtcor_6x9).T

thresholds = [0.5, 2, 5, 10, 30]
fig_name = input('Enter figure name: ')

fig, axes = plt.subplots(1, 5, figsize=(25, 5), sharey=True)
plt.suptitle(f'CSI for different thresholds (data version: {fig_name})')
for i, threshold in enumerate(thresholds):
    ax = axes[i]
    ax.plot(lead_times_mins, csi_values_4x9[i], marker='o', label='Our data 4x9y')
    ax.plot(lead_times_mins, csi_values_rtcor_6x9[i], marker='o', label='Our data 6x9y')
    ax.plot(lead_times_mins, csi_values_rtcor_9x9[i], marker='o', label='Our data 9x9y')
    ax.plot(lead_times_mins, csi_values_rtcor_4x20[i], marker='o', label='Our data 4x20y')
    ax.plot(lead_times_mins, csi_values_pretrained[i], marker='o', label='Pretrained 9x9y')
    ax.set_title(f'CSI for threshold {threshold} mm/h')
    ax.set_xlabel('Lead Time (mins)')
    if i == 0:
        ax.set_ylabel('CSI')
    ax.legend()

plt.tight_layout()
plt.savefig(f'../results/figures/csi_thresholds_full_test_{fig_name}.png')
plt.show()

# %%
lead_times = [1, 2, 4, 6, 9]
lead_times_mins = [lt * 5 for lt in lead_times]

hss_values_4x9 = [rainformer_4x9_1['hss_down'], rainformer_4x9_2['hss_down'], rainformer_4x9_4['hss_down'], rainformer_4x9_6['hss_down'], rainformer_4x9_9['hss_down']]
hss_values_4x9 = np.array(hss_values_4x9).T

hss_values_pretrained = [rainformer_pretrained_9x9_1['hss_down'], rainformer_pretrained_9x9_2['hss_down'], rainformer_pretrained_9x9_4['hss_down'], rainformer_pretrained_9x9_6['hss_down'], rainformer_pretrained_9x9_9['hss_down']]
hss_values_pretrained = np.array(hss_values_pretrained).T

hss_values_rtcor_9x9 = [rainformer_rtcor_9x9_1['hss_down'], rainformer_rtcor_9x9_2['hss_down'], rainformer_rtcor_9x9_4['hss_down'], rainformer_rtcor_9x9_6['hss_down'], rainformer_rtcor_9x9_9['hss_down']]
hss_values_rtcor_9x9 = np.array(hss_values_rtcor_9x9).T

hss_values_rtcor_4x20 = [rainformer_rtcor_4x20_1['hss_down'], rainformer_rtcor_4x20_2['hss_down'], rainformer_rtcor_4x20_4['hss_down'], rainformer_rtcor_4x20_6['hss_down'], rainformer_rtcor_4x20_9['hss_down']]
hss_values_rtcor_4x20 = np.array(hss_values_rtcor_4x20).T

hss_values_rtcor_6x9 = [rainformer_rtcor_6x9_1['hss_down'], rainformer_rtcor_6x9_2['hss_down'], rainformer_rtcor_6x9_4['hss_down'], rainformer_rtcor_6x9_6['hss_down'], rainformer_rtcor_6x9_9['hss_down']]
hss_values_rtcor_6x9 = np.array(hss_values_rtcor_6x9).T

thresholds = [0.5, 2, 5, 10, 30]
fig_name = input('Enter figure name: ')

fig, axes = plt.subplots(1, 5, figsize=(25, 5), sharey=True)
for i, threshold in enumerate(thresholds):
    ax = axes[i]
    ax.plot(lead_times_mins, hss_values_4x9[i], marker='o', label='Our data 4x9y')
    ax.plot(lead_times_mins, hss_values_rtcor_6x9[i], marker='o', label='Our data 6x9y')
    ax.plot(lead_times_mins, hss_values_rtcor_9x9[i], marker='o', label='Our data 9x9y')
    ax.plot(lead_times_mins, hss_values_rtcor_4x20[i], marker='o', label='Our data 4x20y')
    ax.plot(lead_times_mins, hss_values_pretrained[i], marker='o', label='Pretrained 9x9y')
    ax.set_title(f'HSS for threshold {threshold} mm/h')
    ax.set_xlabel('Lead Time (mins)')
    if i == 0:
        ax.set_ylabel('HSS')
    ax.legend()

plt.tight_layout()
plt.savefig(f'../results/figures/hss_thresholds_full_test_{fig_name}.png')
plt.show()

# %%
lead_times = [1, 2, 4, 6, 9]
lead_times_mins = [lt * 5 for lt in lead_times]

mse_values_4x9 = [rainformer_4x9_1['mse_down'], rainformer_4x9_2['mse_down'], rainformer_4x9_4['mse_down'], rainformer_4x9_6['mse_down'], rainformer_4x9_9['mse_down']]
mse_values_4x9 = np.array(mse_values_4x9).T

mse_values_pretrained = [rainformer_pretrained_9x9_1['mse_down'], rainformer_pretrained_9x9_2['mse_down'], rainformer_pretrained_9x9_4['mse_down'], rainformer_pretrained_9x9_6['mse_down'], rainformer_pretrained_9x9_9['mse_down']]
mse_values_pretrained = np.array(mse_values_pretrained).T

mse_values_rtcor_9x9 = [rainformer_rtcor_9x9_1['mse_down'], rainformer_rtcor_9x9_2['mse_down'], rainformer_rtcor_9x9_4['mse_down'], rainformer_rtcor_9x9_6['mse_down'], rainformer_rtcor_9x9_9['mse_down']]
mse_values_rtcor_9x9 = np.array(mse_values_rtcor_9x9).T

mse_values_rtcor_4x20 = [rainformer_rtcor_4x20_1['mse_down'], rainformer_rtcor_4x20_2['mse_down'], rainformer_rtcor_4x20_4['mse_down'], rainformer_rtcor_4x20_6['mse_down'], rainformer_rtcor_4x20_9['mse_down']]
mse_values_rtcor_4x20 = np.array(mse_values_rtcor_4x20).T

mse_values_rtcor_6x9 = [rainformer_rtcor_6x9_1['mse_down'], rainformer_rtcor_6x9_2['mse_down'], rainformer_rtcor_6x9_4['mse_down'], rainformer_rtcor_6x9_6['mse_down'], rainformer_rtcor_6x9_9['mse_down']]
mse_values_rtcor_6x9 = np.array(mse_values_rtcor_6x9).T

fig_name = input('Enter figure name: ')

# fig, axes = plt.subplots(1, 5, figsize=(25, 5), sharey=True)
plt.figure(figsize=(5, 3))
# for i, threshold in enumerate(thresholds):
# ax = axes[i]
plt.plot(lead_times_mins, mse_values_4x9, marker='o', label='Our data 4x9y')
plt.plot(lead_times_mins, mse_values_rtcor_6x9, marker='o', label='Our data 6x9y')
plt.plot(lead_times_mins, mse_values_rtcor_9x9, marker='o', label='Our data 9x9y')
plt.plot(lead_times_mins, mse_values_rtcor_4x20, marker='o', label='Our data 4x20y')
plt.plot(lead_times_mins, mse_values_pretrained, marker='o', label='Pretrained 9x9y')
plt.title(f'MSE for threshold {threshold} mm/h')
plt.xlabel('Lead Time (mins)')
# if i == 0:
plt.ylabel('MSE')
plt.legend()

plt.tight_layout()
plt.savefig(f'../results/figures/mse_thresholds_full_test_{fig_name}.png')
plt.show()

# %%
lead_times = [1, 2, 4, 6, 9]
lead_times_mins = [lt * 5 for lt in lead_times]

mae_values_4x9 = [rainformer_4x9_1['mae_down'], rainformer_4x9_2['mae_down'], rainformer_4x9_4['mae_down'], rainformer_4x9_6['mae_down'], rainformer_4x9_9['mae_down']]
mae_values_4x9 = np.array(mae_values_4x9).T

mae_values_pretrained = [rainformer_pretrained_9x9_1['mae_down'], rainformer_pretrained_9x9_2['mae_down'], rainformer_pretrained_9x9_4['mae_down'], rainformer_pretrained_9x9_6['mae_down'], rainformer_pretrained_9x9_9['mae_down']]
mae_values_pretrained = np.array(mae_values_pretrained).T

mae_values_rtcor_9x9 = [rainformer_rtcor_9x9_1['mae_down'], rainformer_rtcor_9x9_2['mae_down'], rainformer_rtcor_9x9_4['mae_down'], rainformer_rtcor_9x9_6['mae_down'], rainformer_rtcor_9x9_9['mae_down']]
mae_values_rtcor_9x9 = np.array(mae_values_rtcor_9x9).T

mae_values_rtcor_4x20 = [rainformer_rtcor_4x20_1['mae_down'], rainformer_rtcor_4x20_2['mae_down'], rainformer_rtcor_4x20_4['mae_down'], rainformer_rtcor_4x20_6['mae_down'], rainformer_rtcor_4x20_9['mae_down']]
mae_values_rtcor_4x20 = np.array(mae_values_rtcor_4x20).T

mae_values_rtcor_6x9 = [rainformer_rtcor_6x9_1['mae_down'], rainformer_rtcor_6x9_2['mae_down'], rainformer_rtcor_6x9_4['mae_down'], rainformer_rtcor_6x9_6['mae_down'], rainformer_rtcor_6x9_9['mae_down']]
mae_values_rtcor_6x9 = np.array(mae_values_rtcor_6x9).T

fig_name = input('Enter figure name: ')

plt.figure(figsize=(5, 3))
plt.plot(lead_times_mins, mae_values_4x9, marker='o', label='Our data 4x9y')
plt.plot(lead_times_mins, mae_values_rtcor_6x9, marker='o', label='Our data 6x9y')
plt.plot(lead_times_mins, mae_values_rtcor_9x9, marker='o', label='Our data 9x9y')
plt.plot(lead_times_mins, mae_values_rtcor_4x20, marker='o', label='Our data 4x20y')
plt.plot(lead_times_mins, mae_values_pretrained, marker='o', label='Pretrained 9x9y')
plt.title(f'MAE for threshold {threshold} mm/h')
plt.xlabel('Lead Time (mins)')
plt.ylabel('MAE')
plt.legend()

plt.tight_layout()
plt.savefig(f'../results/figures/mae_thresholds_full_test_{fig_name}.png')
plt.show()

# %% [markdown]
# ## Heavy set

# %% [markdown]
# ### Load results

# %%
rainformer_pretrained_HEAVY_1 = np.load("../results/metrics_PreTrainModel__9x9y_HEAVY_first_1_outputs.npy", allow_pickle=True).item()
rainformer_pretrained_HEAVY_2 = np.load("../results/metrics_PreTrainModel__9x9y_HEAVY_first_2_outputs.npy", allow_pickle=True).item()
rainformer_pretrained_HEAVY_4 = np.load("../results/metrics_PreTrainModel__9x9y_HEAVY_first_4_outputs.npy", allow_pickle=True).item()
rainformer_pretrained_HEAVY_6 = np.load("../results/metrics_PreTrainModel__9x9y_HEAVY_first_6_outputs.npy", allow_pickle=True).item()
rainformer_pretrained_HEAVY_9 = np.load("../results/metrics_PreTrainModel__9x9y_HEAVY_first_9_outputs.npy", allow_pickle=True).item()

rainformer_4x9y_HEAVY_1 = np.load("../results/metrics_rainformer_4x9y_03_12_epoch23_4x9y_HEAVY_first_1_outputs.npy", allow_pickle=True).item()
rainformer_4x9y_HEAVY_2 = np.load("../results/metrics_rainformer_4x9y_03_12_epoch23_4x9y_HEAVY_first_2_outputs.npy", allow_pickle=True).item()
rainformer_4x9y_HEAVY_4 = np.load("../results/metrics_rainformer_4x9y_03_12_epoch23_4x9y_HEAVY_first_4_outputs.npy", allow_pickle=True).item()
rainformer_4x9y_HEAVY_6 = np.load("../results/metrics_rainformer_4x9y_03_12_epoch23_4x9y_HEAVY_first_6_outputs.npy", allow_pickle=True).item()
rainformer_4x9y_HEAVY_9 = np.load("../results/metrics_rainformer_4x9y_03_12_epoch23_4x9y_HEAVY_first_9_outputs.npy", allow_pickle=True).item()

rainformer_4x20y_HEAVY_1 = np.load("../results/metrics_rainformer_ddp_24_11_17_4x20y_HEAVY_first_1_outputs.npy", allow_pickle=True).item()
rainformer_4x20y_HEAVY_2 = np.load("../results/metrics_rainformer_ddp_24_11_17_4x20y_HEAVY_first_2_outputs.npy", allow_pickle=True).item()
rainformer_4x20y_HEAVY_4 = np.load("../results/metrics_rainformer_ddp_24_11_17_4x20y_HEAVY_first_4_outputs.npy", allow_pickle=True).item()
rainformer_4x20y_HEAVY_6 = np.load("../results/metrics_rainformer_ddp_24_11_17_4x20y_HEAVY_first_6_outputs.npy", allow_pickle=True).item()
rainformer_4x20y_HEAVY_9 = np.load("../results/metrics_rainformer_ddp_24_11_17_4x20y_HEAVY_first_9_outputs.npy", allow_pickle=True).item()

rainformer_6x9y_HEAVY_1 = np.load("../results/metrics_train_rainformer_6x9_30_6x9y_HEAVY_first_1_outputs.npy", allow_pickle=True).item()
rainformer_6x9y_HEAVY_2 = np.load("../results/metrics_train_rainformer_6x9_30_6x9y_HEAVY_first_2_outputs.npy", allow_pickle=True).item()
rainformer_6x9y_HEAVY_4 = np.load("../results/metrics_train_rainformer_6x9_30_6x9y_HEAVY_first_4_outputs.npy", allow_pickle=True).item()
rainformer_6x9y_HEAVY_6 = np.load("../results/metrics_train_rainformer_6x9_30_6x9y_HEAVY_first_6_outputs.npy", allow_pickle=True).item()
rainformer_6x9y_HEAVY_9 = np.load("../results/metrics_train_rainformer_6x9_30_6x9y_HEAVY_first_9_outputs.npy", allow_pickle=True).item()

rainformer_9x9y_HEAVY_1 = np.load("../results/metrics_train_rainformer_9x9_consistent_data_26_9x9y_HEAVY_first_1_outputs.npy", allow_pickle=True).item()
rainformer_9x9y_HEAVY_2 = np.load("../results/metrics_train_rainformer_9x9_consistent_data_26_9x9y_HEAVY_first_2_outputs.npy", allow_pickle=True).item()
rainformer_9x9y_HEAVY_4 = np.load("../results/metrics_train_rainformer_9x9_consistent_data_26_9x9y_HEAVY_first_4_outputs.npy", allow_pickle=True).item()
rainformer_9x9y_HEAVY_6 = np.load("../results/metrics_train_rainformer_9x9_consistent_data_26_9x9y_HEAVY_first_6_outputs.npy", allow_pickle=True).item()
rainformer_9x9y_HEAVY_9 = np.load("../results/metrics_train_rainformer_9x9_consistent_data_26_9x9y_HEAVY_first_9_outputs.npy", allow_pickle=True).item()

# %% [markdown]
# ### visualise results

# %%
lead_times = [1, 2, 4, 6, 9]
lead_times_mins = [lt * 5 for lt in lead_times]

csi_values_pretrained_HEAVY = [rainformer_pretrained_HEAVY_1['csi_down'], rainformer_pretrained_HEAVY_2['csi_down'], rainformer_pretrained_HEAVY_4['csi_down'], rainformer_pretrained_HEAVY_6['csi_down'], rainformer_pretrained_HEAVY_9['csi_down']]
csi_values_pretrained_HEAVY = np.array(csi_values_pretrained_HEAVY).T

csi_values_4x9y_HEAVY = [rainformer_4x9y_HEAVY_1['csi_down'], rainformer_4x9y_HEAVY_2['csi_down'], rainformer_4x9y_HEAVY_4['csi_down'], rainformer_4x9y_HEAVY_6['csi_down'], rainformer_4x9y_HEAVY_9['csi_down']]
csi_values_4x9y_HEAVY = np.array(csi_values_4x9y_HEAVY).T

csi_values_4x20y_HEAVY = [rainformer_4x20y_HEAVY_1['csi_down'], rainformer_4x20y_HEAVY_2['csi_down'], rainformer_4x20y_HEAVY_4['csi_down'], rainformer_4x20y_HEAVY_6['csi_down'], rainformer_4x20y_HEAVY_9['csi_down']]
csi_values_4x20y_HEAVY = np.array(csi_values_4x20y_HEAVY).T

csi_values_6x9y_HEAVY = [rainformer_6x9y_HEAVY_1['csi_down'], rainformer_6x9y_HEAVY_2['csi_down'], rainformer_6x9y_HEAVY_4['csi_down'], rainformer_6x9y_HEAVY_6['csi_down'], rainformer_6x9y_HEAVY_9['csi_down']]
csi_values_6x9y_HEAVY = np.array(csi_values_6x9y_HEAVY).T

csi_values_9x9y_HEAVY = [rainformer_9x9y_HEAVY_1['csi_down'], rainformer_9x9y_HEAVY_2['csi_down'], rainformer_9x9y_HEAVY_4['csi_down'], rainformer_9x9y_HEAVY_6['csi_down'], rainformer_9x9y_HEAVY_9['csi_down']]
csi_values_9x9y_HEAVY = np.array(csi_values_9x9y_HEAVY).T

thresholds = [0.5, 2, 5, 10, 30]
fig_name = input('Enter figure name: ')

fig, axes = plt.subplots(1, 5, figsize=(25, 5), sharey=True)
for i, threshold in enumerate(thresholds):
    ax = axes[i]
    ax.plot(lead_times_mins, csi_values_4x9y_HEAVY[i], marker='o', label='rtcor 4x9y')
    ax.plot(lead_times_mins, csi_values_6x9y_HEAVY[i], marker='o', label='rtcor 6x9y')
    ax.plot(lead_times_mins, csi_values_9x9y_HEAVY[i], marker='o', label='rtcor 9x9y')
    ax.plot(lead_times_mins, csi_values_4x20y_HEAVY[i], marker='o', label='rtcor 4x20y')
    ax.plot(lead_times_mins, csi_values_pretrained_HEAVY[i], marker='o', label='Pretrained 9x9y')
    ax.set_title(f'CSI for threshold {threshold} mm/h')
    ax.set_xlabel('Lead Time (mins)')
    if i == 0:
        ax.set_ylabel('CSI')
    ax.legend()

plt.tight_layout()
plt.savefig(f'../results/figures/csi_thresholds_heavy_test_{fig_name}.png')
plt.show()

# %% [markdown]
# ## Light set

# %% [markdown]
# ### Load results

# %%
rainformer_pretrained_LIGHT_1 = np.load("../results/metrics_PreTrainModel__9x9y_LIGHT_first_1_outputs.npy", allow_pickle=True).item()
rainformer_pretrained_LIGHT_2 = np.load("../results/metrics_PreTrainModel__9x9y_LIGHT_first_2_outputs.npy", allow_pickle=True).item()
rainformer_pretrained_LIGHT_4 = np.load("../results/metrics_PreTrainModel__9x9y_LIGHT_first_4_outputs.npy", allow_pickle=True).item()
rainformer_pretrained_LIGHT_6 = np.load("../results/metrics_PreTrainModel__9x9y_LIGHT_first_6_outputs.npy", allow_pickle=True).item()
rainformer_pretrained_LIGHT_9 = np.load("../results/metrics_PreTrainModel__9x9y_LIGHT_first_9_outputs.npy", allow_pickle=True).item()

rainformer_4x9y_LIGHT_1 = np.load("../results/metrics_rainformer_4x9y_03_12_epoch23_4x9y_LIGHT_first_1_outputs.npy", allow_pickle=True).item()
rainformer_4x9y_LIGHT_2 = np.load("../results/metrics_rainformer_4x9y_03_12_epoch23_4x9y_LIGHT_first_2_outputs.npy", allow_pickle=True).item()
rainformer_4x9y_LIGHT_4 = np.load("../results/metrics_rainformer_4x9y_03_12_epoch23_4x9y_LIGHT_first_4_outputs.npy", allow_pickle=True).item()
rainformer_4x9y_LIGHT_6 = np.load("../results/metrics_rainformer_4x9y_03_12_epoch23_4x9y_LIGHT_first_6_outputs.npy", allow_pickle=True).item()
rainformer_4x9y_LIGHT_9 = np.load("../results/metrics_rainformer_4x9y_03_12_epoch23_4x9y_LIGHT_first_9_outputs.npy", allow_pickle=True).item()

rainformer_4x20y_LIGHT_1 = np.load("../results/metrics_rainformer_ddp_24_11_17_4x20y_LIGHT_first_1_outputs.npy", allow_pickle=True).item()
rainformer_4x20y_LIGHT_2 = np.load("../results/metrics_rainformer_ddp_24_11_17_4x20y_LIGHT_first_2_outputs.npy", allow_pickle=True).item()
rainformer_4x20y_LIGHT_4 = np.load("../results/metrics_rainformer_ddp_24_11_17_4x20y_LIGHT_first_4_outputs.npy", allow_pickle=True).item()
rainformer_4x20y_LIGHT_6 = np.load("../results/metrics_rainformer_ddp_24_11_17_4x20y_LIGHT_first_6_outputs.npy", allow_pickle=True).item()
rainformer_4x20y_LIGHT_9 = np.load("../results/metrics_rainformer_ddp_24_11_17_4x20y_LIGHT_first_9_outputs.npy", allow_pickle=True).item()

rainformer_6x9y_LIGHT_1 = np.load("../results/metrics_train_rainformer_6x9_30_6x9y_LIGHT_first_1_outputs.npy", allow_pickle=True).item()
rainformer_6x9y_LIGHT_2 = np.load("../results/metrics_train_rainformer_6x9_30_6x9y_LIGHT_first_2_outputs.npy", allow_pickle=True).item()
rainformer_6x9y_LIGHT_4 = np.load("../results/metrics_train_rainformer_6x9_30_6x9y_LIGHT_first_4_outputs.npy", allow_pickle=True).item()
rainformer_6x9y_LIGHT_6 = np.load("../results/metrics_train_rainformer_6x9_30_6x9y_LIGHT_first_6_outputs.npy", allow_pickle=True).item()
rainformer_6x9y_LIGHT_9 = np.load("../results/metrics_train_rainformer_6x9_30_6x9y_LIGHT_first_9_outputs.npy", allow_pickle=True).item()

rainformer_9x9y_LIGHT_1 = np.load("../results/metrics_train_rainformer_9x9_consistent_data_26_9x9y_LIGHT_first_1_outputs.npy", allow_pickle=True).item()
rainformer_9x9y_LIGHT_2 = np.load("../results/metrics_train_rainformer_9x9_consistent_data_26_9x9y_LIGHT_first_2_outputs.npy", allow_pickle=True).item()
rainformer_9x9y_LIGHT_4 = np.load("../results/metrics_train_rainformer_9x9_consistent_data_26_9x9y_LIGHT_first_4_outputs.npy", allow_pickle=True).item()
rainformer_9x9y_LIGHT_6 = np.load("../results/metrics_train_rainformer_9x9_consistent_data_26_9x9y_LIGHT_first_6_outputs.npy", allow_pickle=True).item()
rainformer_9x9y_LIGHT_9 = np.load("../results/metrics_train_rainformer_9x9_consistent_data_26_9x9y_LIGHT_first_9_outputs.npy", allow_pickle=True).item()

# %% [markdown]
# ### Visualise results

# %%
lead_times = [1, 2, 4, 6, 9]
lead_times_mins = [lt * 5 for lt in lead_times]

csi_values_pretrained_LIGHT = [rainformer_pretrained_LIGHT_1['csi_down'], rainformer_pretrained_LIGHT_2['csi_down'], rainformer_pretrained_LIGHT_4['csi_down'], rainformer_pretrained_LIGHT_6['csi_down'], rainformer_pretrained_LIGHT_9['csi_down']]
csi_values_pretrained_LIGHT = np.array(csi_values_pretrained_LIGHT).T

csi_values_4x9y_LIGHT = [rainformer_4x9y_LIGHT_1['csi_down'], rainformer_4x9y_LIGHT_2['csi_down'], rainformer_4x9y_LIGHT_4['csi_down'], rainformer_4x9y_LIGHT_6['csi_down'], rainformer_4x9y_LIGHT_9['csi_down']]
csi_values_4x9y_LIGHT = np.array(csi_values_4x9y_LIGHT).T

csi_values_4x20y_LIGHT = [rainformer_4x20y_LIGHT_1['csi_down'], rainformer_4x20y_LIGHT_2['csi_down'], rainformer_4x20y_LIGHT_4['csi_down'], rainformer_4x20y_LIGHT_6['csi_down'], rainformer_4x20y_LIGHT_9['csi_down']]
csi_values_4x20y_LIGHT = np.array(csi_values_4x20y_LIGHT).T

csi_values_6x9y_LIGHT = [rainformer_6x9y_LIGHT_1['csi_down'], rainformer_6x9y_LIGHT_2['csi_down'], rainformer_6x9y_LIGHT_4['csi_down'], rainformer_6x9y_LIGHT_6['csi_down'], rainformer_6x9y_LIGHT_9['csi_down']]
csi_values_6x9y_LIGHT = np.array(csi_values_6x9y_LIGHT).T

csi_values_9x9y_LIGHT = [rainformer_9x9y_LIGHT_1['csi_down'], rainformer_9x9y_LIGHT_2['csi_down'], rainformer_9x9y_LIGHT_4['csi_down'], rainformer_9x9y_LIGHT_6['csi_down'], rainformer_9x9y_LIGHT_9['csi_down']]
csi_values_9x9y_LIGHT = np.array(csi_values_9x9y_LIGHT).T

thresholds = [0.5, 2, 5, 10, 30]
fig_name = input('Enter figure name: ')

fig, axes = plt.subplots(1, 5, figsize=(25, 5), sharey=True)
for i, threshold in enumerate(thresholds):
    ax = axes[i]
    ax.plot(lead_times_mins, csi_values_4x9y_LIGHT[i], marker='o', label='rtcor 4x9y')
    ax.plot(lead_times_mins, csi_values_6x9y_LIGHT[i], marker='o', label='rtcor 6x9y')
    ax.plot(lead_times_mins, csi_values_9x9y_LIGHT[i], marker='o', label='rtcor 9x9y')
    ax.plot(lead_times_mins, csi_values_4x20y_LIGHT[i], marker='o', label='rtcor 4x20y')
    ax.plot(lead_times_mins, csi_values_pretrained_LIGHT[i], marker='o', label='Pretrained 9x9y')
    ax.set_title(f'CSI for threshold {threshold} mm/h')
    ax.set_xlabel('Lead Time (mins)')
    if i == 0:
        ax.set_ylabel('CSI')
    ax.legend()

plt.tight_layout()
plt.savefig(f'../results/figures/csi_thresholds_light_test_{fig_name}.png')
plt.show()

# %%
lead_times = [1, 2, 4, 6, 9]
lead_times_mins = [lt * 5 for lt in lead_times]

hss_values_pretrained_LIGHT = [rainformer_pretrained_LIGHT_1['hss_down'], rainformer_pretrained_LIGHT_2['hss_down'], rainformer_pretrained_LIGHT_4['hss_down'], rainformer_pretrained_LIGHT_6['hss_down'], rainformer_pretrained_LIGHT_9['hss_down']]
hss_values_pretrained_LIGHT = np.array(hss_values_pretrained_LIGHT).T

hss_values_4x9y_LIGHT = [rainformer_4x9y_LIGHT_1['hss_down'], rainformer_4x9y_LIGHT_2['hss_down'], rainformer_4x9y_LIGHT_4['hss_down'], rainformer_4x9y_LIGHT_6['hss_down'], rainformer_4x9y_LIGHT_9['hss_down']]
hss_values_4x9y_LIGHT = np.array(hss_values_4x9y_LIGHT).T

hss_values_4x20y_LIGHT = [rainformer_4x20y_LIGHT_1['hss_down'], rainformer_4x20y_LIGHT_2['hss_down'], rainformer_4x20y_LIGHT_4['hss_down'], rainformer_4x20y_LIGHT_6['hss_down'], rainformer_4x20y_LIGHT_9['hss_down']]
hss_values_4x20y_LIGHT = np.array(hss_values_4x20y_LIGHT).T

hss_values_6x9y_LIGHT = [rainformer_6x9y_LIGHT_1['hss_down'], rainformer_6x9y_LIGHT_2['hss_down'], rainformer_6x9y_LIGHT_4['hss_down'], rainformer_6x9y_LIGHT_6['hss_down'], rainformer_6x9y_LIGHT_9['hss_down']]
hss_values_6x9y_LIGHT = np.array(hss_values_6x9y_LIGHT).T

hss_values_9x9y_LIGHT = [rainformer_9x9y_LIGHT_1['hss_down'], rainformer_9x9y_LIGHT_2['hss_down'], rainformer_9x9y_LIGHT_4['hss_down'], rainformer_9x9y_LIGHT_6['hss_down'], rainformer_9x9y_LIGHT_9['hss_down']]
hss_values_9x9y_LIGHT = np.array(hss_values_9x9y_LIGHT).T

thresholds = [0.5, 2, 5, 10, 30]
fig_name = input('Enter figure name: ')

fig, axes = plt.subplots(1, 5, figsize=(25, 5), sharey=True)
for i, threshold in enumerate(thresholds):
    ax = axes[i]
    ax.plot(lead_times_mins, hss_values_4x9y_LIGHT[i], marker='o', label='rtcor 4x9y')
    ax.plot(lead_times_mins, hss_values_6x9y_LIGHT[i], marker='o', label='rtcor 6x9y')
    ax.plot(lead_times_mins, hss_values_9x9y_LIGHT[i], marker='o', label='rtcor 9x9y')
    ax.plot(lead_times_mins, hss_values_4x20y_LIGHT[i], marker='o', label='rtcor 4x20y')
    ax.plot(lead_times_mins, hss_values_pretrained_LIGHT[i], marker='o', label='Pretrained 9x9y')
    ax.set_title(f'HSS for threshold {threshold} mm/h')
    ax.set_xlabel('Lead Time (mins)')
    if i == 0:
        ax.set_ylabel('HSS')
    ax.legend()

plt.tight_layout()
plt.savefig(f'../results/figures/hss_thresholds_light_test_{fig_name}.png')
plt.show()

# %% [markdown]
# ### Evaluation of models trained on datasets based on 9x9y sequences

# %% [markdown]
# where 9x9y was generated without restrictions of other sequences, and 4x9y and 6x9y are made by cropping the inputs of 9x9y to the last 4 and 6 images, respectively.

# %%
rainformer_4x9y_from_9x9y_1 = np.load("../results/metrics_train_rainformer_4x9y_cropped_from_9x9y_epoch56_4x9y_first_1_outputs.npy", allow_pickle=True).item()
rainformer_4x9y_from_9x9y_2 = np.load("../results/metrics_train_rainformer_4x9y_cropped_from_9x9y_epoch56_4x9y_first_2_outputs.npy", allow_pickle=True).item()
rainformer_4x9y_from_9x9y_4 = np.load("../results/metrics_train_rainformer_4x9y_cropped_from_9x9y_epoch56_4x9y_first_4_outputs.npy", allow_pickle=True).item()
rainformer_4x9y_from_9x9y_6 = np.load("../results/metrics_train_rainformer_4x9y_cropped_from_9x9y_epoch56_4x9y_first_6_outputs.npy", allow_pickle=True).item()
rainformer_4x9y_from_9x9y_9 = np.load("../results/metrics_train_rainformer_4x9y_cropped_from_9x9y_epoch56_4x9y_first_9_outputs.npy", allow_pickle=True).item()


rainformer_6x9y_from_9x9y_9 = np.load("../results/metrics_train_rainformer_6x9y_cropped_from_9x9y_epoch52_6x9y_first_9_outputs.npy", allow_pickle=True).item()
rainformer_6x9y_from_9x9y_6 = np.load("../results/metrics_train_rainformer_6x9y_cropped_from_9x9y_epoch52_6x9y_first_6_outputs.npy", allow_pickle=True).item()
rainformer_6x9y_from_9x9y_4 = np.load("../results/metrics_train_rainformer_6x9y_cropped_from_9x9y_epoch52_6x9y_first_4_outputs.npy", allow_pickle=True).item()
rainformer_6x9y_from_9x9y_2 = np.load("../results/metrics_train_rainformer_6x9y_cropped_from_9x9y_epoch52_6x9y_first_2_outputs.npy", allow_pickle=True).item()
rainformer_6x9y_from_9x9y_1 = np.load("../results/metrics_train_rainformer_6x9y_cropped_from_9x9y_epoch52_6x9y_first_1_outputs.npy", allow_pickle=True).item()

rainformer_9x9y_all_9 = np.load("../results/metrics_train_rainformer_9x9y_all_55_9x9y_first_9_outputs.npy", allow_pickle=True).item()
rainformer_9x9y_all_6 = np.load("../results/metrics_train_rainformer_9x9y_all_55_9x9y_first_6_outputs.npy", allow_pickle=True).item()
rainformer_9x9y_all_4 = np.load("../results/metrics_train_rainformer_9x9y_all_55_9x9y_first_4_outputs.npy", allow_pickle=True).item()
rainformer_9x9y_all_2 = np.load("../results/metrics_train_rainformer_9x9y_all_55_9x9y_first_2_outputs.npy", allow_pickle=True).item()
rainformer_9x9y_all_1 = np.load("../results/metrics_train_rainformer_9x9y_all_55_9x9y_first_1_outputs.npy", allow_pickle=True).item()

# %%
lead_times = [1, 2, 4, 6, 9]
lead_times_mins = [lt * 5 for lt in lead_times]

csi_values_4x9y_from_9x9y = [rainformer_4x9y_from_9x9y_1['csi_down'], rainformer_4x9y_from_9x9y_2['csi_down'], rainformer_4x9y_from_9x9y_4['csi_down'], rainformer_4x9y_from_9x9y_6['csi_down'], rainformer_4x9y_from_9x9y_9['csi_down']]
csi_values_4x9y_from_9x9y = np.array(csi_values_4x9y_from_9x9y).T

csi_values_6x9y_from_9x9y = [rainformer_6x9y_from_9x9y_1['csi_down'], rainformer_6x9y_from_9x9y_2['csi_down'], rainformer_6x9y_from_9x9y_4['csi_down'], rainformer_6x9y_from_9x9y_6['csi_down'], rainformer_6x9y_from_9x9y_9['csi_down']]
csi_values_6x9y_from_9x9y = np.array(csi_values_6x9y_from_9x9y).T

csi_values_9x9y_all = [rainformer_9x9y_all_1['csi_down'], rainformer_9x9y_all_2['csi_down'], rainformer_9x9y_all_4['csi_down'], rainformer_9x9y_all_6['csi_down'], rainformer_9x9y_all_9['csi_down']]
csi_values_9x9y_all = np.array(csi_values_9x9y_all).T

thresholds = [0.5, 2, 5, 10, 30]
fig_name = input('Enter figure name: ')

fig, axes = plt.subplots(1, 5, figsize=(25, 5), sharey=True)
plt.suptitle(f'CSI for different thresholds (data version: {fig_name})')
for i, threshold in enumerate(thresholds):
    ax = axes[i]
    ax.plot(lead_times_mins, csi_values_4x9y_from_9x9y[i], marker='o', label='4x9y from 9x9y')
    ax.plot(lead_times_mins, csi_values_6x9y_from_9x9y[i], marker='o', label='6x9y from 9x9y')
    ax.plot(lead_times_mins, csi_values_9x9y_all[i], marker='o', label='9x9y all')
    ax.set_title(f'CSI for threshold {threshold} mm/h')
    ax.set_xlabel('Lead Time (mins)')
    if i == 0:
        ax.set_ylabel('CSI')
    ax.legend()

plt.tight_layout()
# plt.savefig(f'../results/figures/csi_thresholds_full_test_{fig_name}.png')
plt.show()

# %% [markdown]
# ### Based on 9x9y, Heavy and Light sets

# %%
"metrics_train_rainformer_4x9y_cropped_from_9x9y_epoch56_4x9y_HEAVY_first_9_outputs.npy"
"metrics_train_rainformer_4x9y_cropped_from_9x9y_epoch56_4x9y_HEAVY_first_6_outputs.npy"
"metrics_train_rainformer_4x9y_cropped_from_9x9y_epoch56_4x9y_HEAVY_first_4_outputs.npy"
"metrics_train_rainformer_4x9y_cropped_from_9x9y_epoch56_4x9y_HEAVY_first_2_outputs.npy"
"metrics_train_rainformer_4x9y_cropped_from_9x9y_epoch56_4x9y_HEAVY_first_1_outputs.npy"

"metrics_train_rainformer_6x9y_cropped_from_9x9y_epoch52_6x9y_HEAVY_first_1_outputs.npy"
"metrics_train_rainformer_6x9y_cropped_from_9x9y_epoch52_6x9y_HEAVY_first_2_outputs.npy"
"metrics_train_rainformer_6x9y_cropped_from_9x9y_epoch52_6x9y_HEAVY_first_4_outputs.npy"
"metrics_train_rainformer_6x9y_cropped_from_9x9y_epoch52_6x9y_HEAVY_first_6_outputs.npy"
"metrics_train_rainformer_6x9y_cropped_from_9x9y_epoch52_6x9y_HEAVY_first_9_outputs.npy"

"metrics_train_rainformer_9x9y_all_55_9x9y_HEAVY_first_9_outputs.npy"
"metrics_train_rainformer_9x9y_all_55_9x9y_HEAVY_first_4_outputs.npy"
"metrics_train_rainformer_9x9y_all_55_9x9y_HEAVY_first_6_outputs.npy"
"metrics_train_rainformer_9x9y_all_55_9x9y_HEAVY_first_2_outputs.npy"
"metrics_train_rainformer_9x9y_all_55_9x9y_HEAVY_first_1_outputs.npy"

# %%
"metrics_train_rainformer_4x9y_cropped_from_9x9y_epoch56_4x9y_LIGHT_first_1_outputs.npy"
"metrics_train_rainformer_4x9y_cropped_from_9x9y_epoch56_4x9y_LIGHT_first_2_outputs.npy"
"metrics_train_rainformer_4x9y_cropped_from_9x9y_epoch56_4x9y_LIGHT_first_9_outputs.npy"
"metrics_train_rainformer_4x9y_cropped_from_9x9y_epoch56_4x9y_LIGHT_first_6_outputs.npy"
"metrics_train_rainformer_4x9y_cropped_from_9x9y_epoch56_4x9y_LIGHT_first_4_outputs.npy"

"metrics_train_rainformer_6x9y_cropped_from_9x9y_epoch52_6x9y_LIGHT_first_9_outputs.npy"
"metrics_train_rainformer_6x9y_cropped_from_9x9y_epoch52_6x9y_LIGHT_first_6_outputs.npy"
"metrics_train_rainformer_6x9y_cropped_from_9x9y_epoch52_6x9y_LIGHT_first_4_outputs.npy"
"metrics_train_rainformer_6x9y_cropped_from_9x9y_epoch52_6x9y_LIGHT_first_2_outputs.npy"
"metrics_train_rainformer_6x9y_cropped_from_9x9y_epoch52_6x9y_LIGHT_first_1_outputs.npy"

"metrics_train_rainformer_9x9y_all_55_9x9y_LIGHT_first_9_outputs.npy"
"metrics_train_rainformer_9x9y_all_55_9x9y_LIGHT_first_6_outputs.npy"
"metrics_train_rainformer_9x9y_all_55_9x9y_LIGHT_first_4_outputs.npy"
"metrics_train_rainformer_9x9y_all_55_9x9y_LIGHT_first_2_outputs.npy"
"metrics_train_rainformer_9x9y_all_55_9x9y_LIGHT_first_1_outputs.npy"
